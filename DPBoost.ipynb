# %%
# !git clone https://github.com/QinbinLi/DPBoost.git
# Out:
# Cloning into 'DPBoost'...
# remote: Enumerating objects: 13928, done.
# remote: Counting objects: 100% (13928/13928), done.
# remote: Compressing objects: 100% (3652/3652), done.
# remote: Total 13928 (delta 10099), reused 13535 (delta 9710), pack-reused 0 (from 0)
# Receiving objects: 100% (13928/13928), 9.92 MiB | 8.03 MiB/s, done.
# Resolving deltas: 100% (10099/10099), done.

# %%
# %pwd
# Out:
# '/content'

# %%
# %ls
# Out:
# DPBoost/  sample_data/

# %%
# %cd DPBoost
# Out:
# /content/DPBoost

# %%
# %ls
# Out:
# abalone             docs/      output.txt       run_exp.py   windows/
# build_r.R           examples/  pmml/            src/
# CMakeLists.txt      helpers/   python-package/  swig/
# CODE_OF_CONDUCT.md  include/   README.md        tests/
# docker/             LICENSE    R-package/       VERSION.txt

# %%
# %cd python-package
# !python3 setup.py install --user
# %cd ..
# !python3 run_exp.py

# %% [markdown]
# # New Section

# %%
# !python3 dp_boost_reg.py
# Out:
# ...
#   REGRESSION — cal-housing  (N=20640, K=8)
# ...
# [LightGBM] [Warning] Unknown parameter: geo_clip
# [LightGBM] [Warning] Unknown parameter: balance_partition
# [LightGBM] [Warning] Unknown parameter: high_level_boost_round
# [LightGBM] [Warning] Unknown parameter: inner_boost_round
# [LightGBM] [Warning] Unknown parameter: boost_method
# [LightGBM] [Warning] Unknown parameter: my_n_trees
# [LightGBM] [Warning] Unknown parameter: total_budget
# [LightGBM] [Warning] Accuracy may be bad since you didn't set num_leaves and 2^max_depth > num_leaves
# [LightGBM] [Warning] Unknown parameter: geo_clip
# [LightGBM] [Warning] Unknown parameter: balance_partition
# [LightGBM] [Warning] Unknown parameter: high_level_boost_round
# [LightGBM] [Warning] Unknown parameter: inner_boost_round
# [LightGBM] [Warning] Unknown parameter: boost_method
# [LightGBM] [Warning] Unknown parameter: my_n_trees
# [LightGBM] [Warning] Unknown parameter: total_budget
# ...

# %%
# !python3 dp_boost_class.py
# Out:
# ...
#   CLASSIFICATION — adult-income  (N=30162, K=14)
# ...
# [LightGBM] [Warning] Unknown parameter: geo_clip
# [LightGBM] [Warning] Unknown parameter: balance_partition
# [LightGBM] [Warning] Unknown parameter: high_level_boost_round
# [LightGBM] [Warning] Unknown parameter: inner_boost_round
# [LightGBM] [Warning] Unknown parameter: boost_method
# [LightGBM] [Warning] Unknown parameter: my_n_trees
# [LightGBM] [Warning] Unknown parameter: total_budget
# [LightGBM] [Warning] Accuracy may be bad since you didn't set num_leaves and 2^max_depth > num_leaves
# [LightGBM] [Warning] Unknown parameter: geo_clip
# [LightGBM] [Warning] Unknown parameter: balance_partition
# [LightGBM] [Warning] Unknown parameter: high_level_boost_round
# [LightGBM] [Warning] Unknown parameter: inner_boost_round
# [LightGBM] [Warning] Unknown parameter: boost_method
# [LightGBM] [Warning] Unknown parameter: my_n_trees
# [LightGBM] [Warning] Unknown parameter: total_budget
# ...
